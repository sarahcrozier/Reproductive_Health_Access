# %%
import numpy as np
import pandas as pd
from pathlib import Path
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.datasets import make_classification
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
# Loading clustered dataset
file = "Resources/MLM/clustered_data.csv"
clustered_df = pd.read_csv(file, index_col=0)
clustered_df
# Out:
#                                                         abortion_status  \
# state
# Alabama                                          Abortion Ban In Effect
# Alaska                                               Abortion Available
# Arizona                                   Status of pre-Roe ban unclear
# Arkansas                                         Abortion Ban In Effect
# California                                           Abortion Available
# Colorado                                             Abortion Available
# Connecticut                                          Abortion Available
# Delaware                                             Abortion Available
# District of Columbia                                 Abortion Available
# Florida               Abortion available, pre-viability gestational ...
# Georgia                              6 week LMP ban currently in effect
# Hawaii                                               Abortion Available
# Idaho                 State abortion ban/restriction not yet impleme...
# Illinois                                             Abortion Available
# Indiana               Abortion available, pre-viability gestational ...
# Iowa                  Abortion available, pre-viability gestational ...
# Kansas                Abortion available, pre-viability gestational ...
# Kentucky                                         Abortion Ban In Effect
# Louisiana                                        Abortion Ban In Effect
# Maine                                                Abortion Available
# Maryland                                             Abortion Available
# Massachusetts                                        Abortion Available
# Michigan                                             Abortion Available
# Minnesota                                            Abortion Available
# Mississippi                                      Abortion Ban In Effect
# Missouri                                         Abortion Ban In Effect
# Montana                                              Abortion Available
# Nebraska              Abortion available, pre-viability gestational ...
# Nevada                                               Abortion Available
# New Hampshire                                        Abortion Available
# New Jersey                                           Abortion Available
# New Mexico                                           Abortion Available
# New York                                             Abortion Available
# North Carolina                                       Abortion Available
# North Dakota          State abortion ban/restriction not yet impleme...
# Ohio                                 6 week LMP ban currently in effect
# Oklahoma                                         Abortion Ban In Effect
# Oregon                                               Abortion Available
# Pennsylvania                                         Abortion Available
# Rhode Island                                         Abortion Available
# South Carolina                       6 week LMP ban currently in effect
# South Dakota                                     Abortion Ban In Effect
# Tennessee                            6 week LMP ban currently in effect
# Texas                                            Abortion Ban In Effect
# Utah                  Abortion ban temporarily blocked, abortion ava...
# Vermont                                              Abortion Available
# Virginia                                             Abortion Available
# Washington                                           Abortion Available
# West Virginia         Abortion ban temporarily blocked, abortion ava...
# Wisconsin                                 Status of pre-Roe ban unclear
# Wyoming               Abortion ban temporarily blocked, abortion ava...
#
#                       total_community_health_centers  uninsured  \
# state
# Alabama                                           17     165700
# Alaska                                            27      29200
# Arizona                                           23     309000
# Arkansas                                          12      83800
# California                                       175    1034300
# Colorado                                          19     204300
# Connecticut                                       16      58100
# Delaware                                           3      24800
# District of Columbia                               8       7600
# Florida                                           47    1011800
# Georgia                                           35     586000
# Hawaii                                            14      18900
# Idaho                                             14      78900
# Illinois                                          45     328700
# Indiana                                           27     131100
# Iowa                                              14      72800
# Kansas                                            19      93200
# Kentucky                                          25     101400
# Louisiana                                         36     133400
# Maine                                             18      24400
# Maryland                                          17      91400
# Massachusetts                                     37      75000
# Arkansas                       52035              0.12       0.70
# California                    155779              0.09       0.68
# Colorado                      103642              0.11       0.67
# Connecticut                     4842              0.07       0.78
# Delaware                        1949              0.09       0.74
# District of Columbia              61              0.06       0.74
# Florida                        53625              0.14       0.74
# Georgia                        57513              0.16       0.71
# Hawaii                          6423              0.06       0.78
# Idaho                          82643              0.10       0.65
# Illinois                       55519              0.10       0.74
# Indiana                        35826              0.10       0.69
# Iowa                           55857              0.07       0.76
# Kansas                         81759              0.10       0.69
# Kentucky                       39486              0.09       0.71
# Louisiana                      43204              0.09       0.78
# Maine                          30843              0.08       0.77
# Maryland                        9707              0.08       0.75
# Massachusetts                   7800              0.06       0.80
# Michigan                       56539              0.08       0.74
# Minnesota                      79627              0.08       0.73
# Mississippi                    46923              0.13       0.71
# Missouri                       68742              0.12       0.71
# Montana                       145546              0.09       0.68
# Nebraska                       76824              0.09       0.70
# Nevada                        109781              0.12       0.69
# New Hampshire                   8953              0.09       0.74
# New Jersey                      7354              0.10       0.73
# New Mexico                    121298              0.09       0.65
# New York                       47126              0.08       0.77
# North Carolina                 48618              0.12       0.75
# North Dakota                   69001              0.07       0.75
# Ohio                           40861              0.09       0.72
# Oklahoma                       68595              0.15       0.68
# Oregon                         95988              0.11       0.72
# Pennsylvania                   44743              0.08       0.74
# Rhode Island                    1034              0.07       0.81
# South Carolina                 30061              0.12       0.76
# South Dakota                   75811              0.07       0.75
# Tennessee                      41235              0.12       0.73
# Texas                         261232              0.17       0.69
# Utah                           82170              0.10       0.64
# Vermont                         9217              0.07       0.68
# Virginia                       39490              0.10       0.75
# Washington                     66456              0.09       0.68
# West Virginia                  24038              0.10       0.74
# Wisconsin                      54158              0.08       0.75
# Wyoming                        97093              0.12       0.64
#
#                       no_provider  ...  abortions_occurring_state  \
# state                              ...
# Alabama                      0.13  ...                       5700
# Alaska                       0.23  ...                       1240
# Arizona                      0.19  ...                      13320
# Arkansas                     0.13  ...                       3250
# California                   0.19  ...                     154060
# Colorado                     0.17  ...                      13420
# Connecticut                  0.10  ...                      11170
# Delaware                     0.12  ...                       1830
# District of Columbia         0.15  ...                       9410
# Florida                      0.20  ...                      77400
# Georgia                      0.17  ...                      41620
# Hawaii                       0.10  ...                       3130
# Idaho                        0.15  ...                       1690
# Illinois                     0.15  ...                      52780
# Indiana                      0.12  ...                       7880
# Iowa                         0.10  ...                       3510
# Kansas                       0.13  ...                       8180
# Kentucky                     0.12  ...                       4080
# Louisiana                    0.12  ...                       7360
# Maine                        0.08  ...                       2370
# Maryland                     0.10  ...                      30750
# Massachusetts                0.07  ...                      17060
# Michigan                     0.08  ...                      31500
# Minnesota                    0.15  ...                      11060
# Mississippi                  0.13  ...                       3560
# Missouri                     0.15  ...                        170
# Montana                      0.17  ...                       1630
# Nebraska                     0.12  ...                       2200
# Nevada                       0.24  ...                      11010
# New Hampshire                0.07  ...                       2050
# New Jersey                   0.13  ...                      48830
# New Mexico                   0.19  ...                       5880
# West Virginia        -0.072754      0
# Wisconsin            -2.673340      1
# Wyoming               2.053162      0
#
# [51 rows x 30 columns]

# %%
clustered_df.dtypes
# Out:
# abortion_status                               object
# total_community_health_centers                 int64
# uninsured                                      int64
# total_insured                                  int64
# maternal_mortality                           float64
# population                                     int64
# land_area_sqmi                                 int64
# no_doctor_visits                             float64
# mammogram                                    float64
# no_provider                                  float64
# pap_smear                                    float64
# prescription_contraception                    object
# otc_methods                                   object
# male_sterilization                            object
# female_sterilization                          object
# cost_sharing                                  object
# teen_births                                  float64
# poverty_under_200                            float64
# percent_of_all_us_abortions                  float64
# percent_residents_traveling_outside_state      int64
# abortions_occurring_state                      int64
# abortions_residence_state                      int64
# no_services                                    int64
# few_services                                   int64
# restricted_services                            int64
# full_service                                   int64
# PC 1                                         float64
# PC 2                                         float64
# PC 3                                         float64
# Class                                          int64
# dtype: object

# %%
# using all features (minus principal components) as independent variables
chc_df = pd.get_dummies(data = clustered_df.drop(columns=['PC 1','PC 2','PC 3','prescription_contraception',
                              'otc_methods','male_sterilization','female_sterilization','cost_sharing']),
                        columns=['abortion_status'])
chc_df.dtypes
# Out:
# total_community_health_centers                                                                        int64
# uninsured                                                                                             int64
# total_insured                                                                                         int64
# maternal_mortality                                                                                  float64
# population                                                                                            int64
# land_area_sqmi                                                                                        int64
# no_doctor_visits                                                                                    float64
# mammogram                                                                                           float64
# no_provider                                                                                         float64
# pap_smear                                                                                           float64
# teen_births                                                                                         float64
# poverty_under_200                                                                                   float64
# percent_of_all_us_abortions                                                                         float64
# percent_residents_traveling_outside_state                                                             int64
# abortions_occurring_state                                                                             int64
# abortions_residence_state                                                                             int64
# no_services                                                                                           int64
# few_services                                                                                          int64
# restricted_services                                                                                   int64
# full_service                                                                                          int64
# Class                                                                                                 int64
# abortion_status_6 week LMP ban currently in effect                                                    uint8
# abortion_status_Abortion Available                                                                    uint8
# abortion_status_Abortion Ban In Effect                                                                uint8
# abortion_status_Abortion available, pre-viability gestational limit in effect                         uint8
# abortion_status_Abortion ban temporarily blocked, abortion available                                  uint8
# abortion_status_State abortion ban/restriction not yet implemented, abortion currently available      uint8
# abortion_status_Status of pre-Roe ban unclear                                                         uint8
# dtype: object

# %%
train_df = chc_df[chc_df['Class']==4]
X_train = train_df.drop(columns=['total_community_health_centers','Class'])
y_train = train_df[['total_community_health_centers']]

# %%
test_df = chc_df[(chc_df['Class']!=4) & (chc_df['Class']!=2)]
X_test = test_df.drop(columns=['total_community_health_centers','Class'])
y_test = test_df[['total_community_health_centers']]
y_test
# Out:
#                 total_community_health_centers
# state
# Alabama                                     17
# Alaska                                      27
# Arizona                                     23
# Arkansas                                    12
# Colorado                                    19
# Florida                                     47
# Georgia                                     35
# Hawaii                                      14
# Idaho                                       14
# Indiana                                     27
# Iowa                                        14
# Kansas                                      19
# Kentucky                                    25
# Louisiana                                   36
# Michigan                                    39
# Minnesota                                   16
# Mississippi                                 20
# Missouri                                    28
# Montana                                     14
# Nebraska                                     7
# New Hampshire                               10
# North Carolina                              39
# North Dakota                                 4
# Ohio                                        51
# Oklahoma                                    21
# Pennsylvania                                42
# Rhode Island                                 8
# South Carolina                              23
# South Dakota                                 4
# Tennessee                                   29
# Texas                                       72
# Utah                                        13
# West Virginia                               28
# Wisconsin                                   16
# Wyoming                                      6

# %%
# Scaling the remaining columns
scalerX = StandardScaler().fit(X_train)
scalery = StandardScaler().fit(y_train)
X_train_scaled = scalerX.transform(X_train)
y_train_scaled = scalery.transform(y_train)
X_test_scaled = scalerX.transform(X_test)
y_test_scaled = scalery.transform(y_test)
X_test_scaled
# Out:
# array([[ 6.33195608e-01,  7.55474735e-03,  3.55776448e+00,
#          2.82344820e-02,  2.57190746e-01,  1.87794214e+00,
#          2.45651842e-01, -6.35641726e-02,  1.84021377e-02,
#          3.05724904e+00,  1.46053397e+00, -7.15018225e-01,
#          2.40711500e+00, -7.12702431e-01, -4.82621623e-01,
#          1.23377418e-01,  9.95235149e-01,  5.00000000e+00,
#         -1.44145888e+00,  0.00000000e+00, -1.00000000e+00,
#          1.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00],
#        [-8.44260811e-01, -1.15439580e+00,  2.02556722e+00,
#         -1.13869783e+00,  1.28464274e+01,  1.87794214e+00,
#         -2.45651842e+00,  2.16118187e+00, -2.30026721e+00,
#          1.33646447e+00,  6.20471599e-01, -1.00943749e+00,
#         -4.36733944e-01, -9.94712189e-01, -1.01686290e+00,
#         -5.96324188e-01, -7.64259074e-01,  0.00000000e+00,
#         -1.03377354e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00],
#        [ 2.18425425e+00,  6.27533139e-01,  2.18538176e+00,
#          6.97295956e-01,  1.78120220e+00,  1.30639453e+00,
#         -1.22825921e+00,  1.27128345e+00, -1.26974750e+00,
#          1.06986405e+00,  8.52829275e-01, -2.43947394e-01,
#         -5.07830168e-01, -2.30883069e-01, -1.54070137e-01,
#          1.70672095e+00,  2.34372783e-01,  7.00000000e+00,
#         -1.44145888e+00,  0.00000000e+00, -1.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  1.00000000e+00],
#        [-2.53278243e-01, -5.44873760e-01,  4.51746204e+00,
#         -5.01239453e-01,  2.90843003e-01,  1.87794214e+00,
#         -7.36955527e-01, -6.35641726e-02, -1.52737743e+00,
#          3.78434111e+00,  1.49628130e+00, -8.91669786e-01,
#          1.69615276e+00, -8.67618105e-01, -7.96678190e-01,
#          2.67317739e-01,  3.77034476e-01,  3.00000000e+00,
#         -1.44145888e+00,  0.00000000e+00, -1.00000000e+00,
#          1.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00],
#        [ 1.05099647e+00,  2.81178046e-01, -4.81560822e-01,
#          2.70697148e-01,  1.54026173e+00,  1.30639453e+00,
#         -1.47391105e+00,  8.26334244e-01, -1.26974750e+00,
#          7.61715502e-02, -5.59190453e-01, -2.43947394e-01,
#         -8.63311285e-01, -2.24559980e-01, -2.91426745e-01,
#          1.41884031e+00,  5.19696170e-01,  0.00000000e+00,
#          8.73611439e-02,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00],
#        [ 9.79126063e+00,  4.55902895e+00,  9.60549374e-01,
#          4.68542935e+00,  3.29337311e-01,  3.02103735e+00,
#          2.45651842e-01,  1.49375806e+00, -2.39227790e-01,
#          7.30554413e-01,  1.33541830e+00,  3.81903852e+00,
#         -8.63311285e-01,  3.82095220e+00,  3.98802538e+00,
#          2.13854191e+00,  5.03731647e+00,  0.00000000e+00,
#          3.45076519e+00,  0.00000000e+00, -1.00000000e+00,
#          0.00000000e+00,  1.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00],
#        [
00000000e+00,
#         -1.44145888e+00,  0.00000000e+00, -1.00000000e+00,
#          1.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00],
#        [ 1.90391637e+00,  5.68218788e-01,  3.32253781e+00,
#          5.66089984e-01,  2.93722294e-02,  1.87794214e+00,
#         -2.72728331e-15,  1.58910432e-01, -4.96857718e-01,
#          2.69370300e+00,  1.37116563e+00, -3.61715102e-01,
#          7.00805631e-01, -3.87063361e-01, -3.86679067e-01,
#         -7.40264509e-01,  1.66098972e+00,  8.00000000e+00,
#         -1.44145888e+00,  1.00000000e+00, -1.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00],
#        [ 1.97232314e+01,  6.72960106e+00,  1.11826349e+00,
#          6.77915632e+00,  5.35555610e+00,  4.73568017e+00,
#         -9.82607369e-01,  2.60613108e+00, -1.01211757e+00,
#          2.47557538e+00,  1.15668162e+00,  2.58247759e+00,
#         -3.65637721e-01,  2.59553760e+00,  3.13696659e+00,
#         -1.64503224e-01,  8.03321204e+00,  1.90000000e+01,
#         -1.44145888e+00,  0.00000000e+00, -1.00000000e+00,
#          1.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00],
#        [ 1.73181705e-02, -4.83708727e-01, -8.96077756e-01,
#         -4.34760995e-01,  1.02041909e+00,  7.34846923e-01,
#         -2.21086658e+00,  8.26334244e-01, -2.55789714e+00,
#         -3.35847290e-01, -8.80916467e-01, -8.91669786e-01,
#         -3.65637721e-01, -8.75838120e-01, -8.85718403e-01,
#         -8.84204830e-01, -7.64259074e-01,  2.00000000e+00,
#         -1.44145888e+00,  0.00000000e+00, -1.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  1.00000000e+00,
#          0.00000000e+00,  0.00000000e+00],
#        [-8.23695483e-01, -8.85214137e-01,  1.08558936e+00,
#         -8.40951262e-01, -3.86971557e-01,  7.34846923e-01,
#          2.45651842e-01, -5.08513381e-01, -4.96857718e-01,
#          2.49981178e+00,  1.47840764e+00, -1.00943749e+00,
#          2.76259611e+00, -1.01051991e+00, -9.85112130e-01,
#         -7.40264509e-01, -3.83827890e-01,  1.00000000e+00,
#         -1.44145888e+00,  0.00000000e+00, -1.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  1.00000000e+00,
#          0.00000000e+00,  0.00000000e+00],
#        [-1.73181705e-02,  3.03848898e-01, -1.46089376e+00,
#          2.89440858e-01,  3.42241378e-01, -4.08248290e-01,
#          4.91303684e-01, -9.53462589e-01, -4.96857718e-01,
#         -1.66192473e-01, -5.59190453e-01, -6.56134371e-01,
#          2.74228291e-01, -6.33031513e-01, -5.35769657e-01,
#         -3.08443545e-01,  1.42322023e+00,  3.00000000e+00,
#         -1.44145888e+00,  0.00000000e+00, -1.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  1.00000000e+00],
#        [-9.53581762e-01, -1.19751668e+00, -1.69624561e-01,
#         -1.17859638e+00,  1.38170875e+00,  1.87794214e+00,
#         -2.21086658e+00,  1.49375806e+00, -2.55789714e+00,
#          1.43341008e+00,  5.66850596e-01, -1.06832135e+00,
#          5.32206016e+00, -1.06679540e+00, -1.05965743e+00,
#         -1.02814515e+00, -5.26489584e-01,  1.00000000e+00,
#         -1.44145888e+00,  0.00000000e+00, -1.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  1.00000000e+00,
#          0.00000000e+00,  0.00000000e+00]])

# %%
# Creating an object of LinearRegression class
LR = LinearRegression()

# Fitting the training data
LR.fit(X_train_scaled, y_train_scaled)
# Out:
# LinearRegression()

# %%
y_pred_scaled = LR.predict(X_test_scaled)
y_pred_scaled
# Out:
# array([[-2.26632539],
#        [11.16698436],
#        [-0.09820302],
#        [-4.85055381],
#        [-0.58444413],
#        [ 6.47551906],
#        [ 0.18234378],
#        [-1.52588449],
#        [-0.9823054 ],
#        [-2.6866812 ],
#        [ 0.02533821],
#        [-2.84241159],
#        [-2.84917612],
#        [-1.80297408],
#        [ 0.16228198],
#        [ 0.35048385],
#        [-3.44823538],
#        [ 0.99228728],
#        [ 0.63369367],
#        [-1.61279559],
#        [-0.75855547],
#        [ 0.75434238],
#        [-0.50439831],
#        [-0.47535369],
#        [-3.9194538 ],
#        [ 1.43785822],
#        [-0.06718896],
#        [-0.6429594 ],
#        [ 2.17517691],
#        [-1.99085116],
#        [14.98364814],
#        [-1.0071466 ],
#        [-1.85413574],
#        [ 1.40182483],
#        [ 0.64861789]])

# %%
# Returning data to pre-scaled format
y_pred = scalery.inverse_transform(y_pred_scaled)
# Out:
# array([[-5.40626154e+00],
#        [ 1.47302521e+02],
#        [ 1.92407788e+01],
#        [-3.47835620e+01],
#        [ 1.37132291e+01],
#        [ 9.39703217e+01],
#        [ 2.24300123e+01],
#        [ 3.01101099e+00],
#        [ 9.19037425e+00],
#        [-1.01848325e+01],
#        [ 2.06451856e+01],
#        [-1.19551631e+01],
#        [-1.20320617e+01],
#        [-1.38921185e-01],
#        [ 2.22019514e+01],
#        [ 2.43414150e+01],
#        [-1.88421190e+01],
#        [ 3.16373847e+01],
#        [ 2.75609214e+01],
#        [ 2.02301255e+00],
#        [ 1.17339454e+01],
#        [ 2.89324462e+01],
#        [ 1.46231836e+01],
#        [ 1.49533605e+01],
#        [-2.41988921e+01],
#        [ 3.67025993e+01],
#        [ 1.95933441e+01],
#        [ 1.30480322e+01],
#        [ 4.50843787e+01],
#        [-2.27469268e+00],
#        [ 1.90690047e+02],
#        [ 8.90798148e+00],
#        [-7.20522783e-01],
#        [ 3.62929746e+01],
#        [ 2.77305787e+01]])

# %%
compare_df = y_test['total_community_health_centers'].to_frame()
compare_df['predictions'] = y_pred.astype(int)
compare_df['addl_chc_needed'] = compare_df['predictions'] - compare_df['total_community_health_centers']
compare_df['Class'] = clustered_df['Class']
#compare_df = compare_df[compare_df['addl_chc_needed']>0]
compare_df.sort_values(by=['addl_chc_needed'],ascending=False)
# Out:
#                 total_community_health_centers  predictions  addl_chc_needed  \
# state
# Alaska                                      27          147              120
# Texas                                       72          190              118
# Florida                                     47           93               46
# South Dakota                                 4           45               41
# Wyoming                                      6           27               21
# Wisconsin                                   16           36               20
# Montana                                     14           27               13
# Rhode Island                                 8           19               11
# North Dakota                                 4           14               10
# Minnesota                                   16           24                8
# Iowa                                        14           20                6
# Missouri                                    28           31                3
# New Hampshire                               10           11                1
# Arizona                                     23           19               -4
# Idaho                                       14            9               -5
# Utah                                        13            8               -5
# Nebraska                                     7            2               -5
# Pennsylvania                                42           36               -6
# Colorado                                    19           13               -6
# South Carolina                              23           13              -10
# North Carolina                              39           28              -11
# Hawaii                                      14            3              -11
# Georgia                                     35           22              -13
# Michigan                                    39           22              -17
# Alabama                                     17           -5              -22
# West Virginia                               28            0              -28
# Kansas                                      19          -11              -30
# Tennessee                                   29           -2              -31
# Louisiana                                   36            0              -36
# Kentucky                                    25          -12              -37
# Indiana                                     27          -10              -37
# Ohio                                        51           14              -37
# Mississippi                                 20          -18              -38
# Oklahoma                                    21          -24              -45
# Arkansas                                    12          -34              -46
#
#                 Class
# state
# Alaska              0
# Texas               3
# Florida             3
# South Dakota        0
# Wyoming             0
# Wisconsin           1
# Montana             0
# Rhode Island        1
# North Dakota        0
# Minnesota           1
# Iowa                1
# Missouri            0
# New Hampshire       1
# Arizona             0
# Idaho               0
# Utah                0
# Nebraska            0
# Pennsylvania        1
# Colorado            1
# South Carolina      0
# North Carolina      1
# Hawaii              1
# Georgia             0
# Michigan            1
# Alabama             0
# West Virginia       0
# Kansas              0
# Tennessee           0
# Louisiana           0
# Kentucky            0
# Indiana             0
# Ohio                0
# Mississippi         0
# Oklahoma            0
# Arkansas            0

# %%
# Getting feature importance
importance = LR.coef_

d = {'Feature':X_train.columns, 'Importance':importance[0]}
fi_df = pd.DataFrame(data=d)
print(fi_df)
fi_df.sort_values(by=['Importance'], ascending=False)
# Out:
#                                               Feature  Importance
# 0                                           uninsured    0.389561
# 1                                       total_insured    0.334030
# 2                                  maternal_mortality   -0.209684
# 3                                          population    0.399309
# 4                                      land_area_sqmi    1.340777
# 5                                    no_doctor_visits   -0.553699
# 6                                           mammogram    0.407875
# 7                                         no_provider   -0.380262
# 8                                           pap_smear   -0.066725
# 9                                         teen_births   -1.122156
# 10                                  poverty_under_200    0.763528
# 11                        percent_of_all_us_abortions    0.556908
# 12          percent_residents_traveling_outside_state    0.717067
# 13                          abortions_occurring_state    0.589229
# 14                          abortions_residence_state   -0.477219
# 15                                        no_services   -0.382452
# 16                                       few_services   -0.006587
# 17                                restricted_services    0.000000
# 18                                       full_service   -0.015340
# 19  abortion_status_6 week LMP ban currently in ef...    0.000000
# 20                 abortion_status_Abortion Available    0.000000
# 21             abortion_status_Abortion Ban In Effect    0.000000
# 22  abortion_status_Abortion available, pre-viabil...    0.000000
# 23  abortion_status_Abortion ban temporarily block...    0.000000
# 24  abortion_status_State abortion ban/restriction...    0.000000
# 25      abortion_status_Status of pre-Roe ban unclear    0.000000
#                                               Feature  Importance
# 4                                      land_area_sqmi    1.340777
# 10                                  poverty_under_200    0.763528
# 12          percent_residents_traveling_outside_state    0.717067
# 13                          abortions_occurring_state    0.589229
# 11                        percent_of_all_us_abortions    0.556908
# 6                                           mammogram    0.407875
# 3                                          population    0.399309
# 0                                           uninsured    0.389561
# 1                                       total_insured    0.334030
# 17                                restricted_services    0.000000
# 19  abortion_status_6 week LMP ban currently in ef...    0.000000
# 24  abortion_status_State abortion ban/restriction...    0.000000
# 23  abortion_status_Abortion ban temporarily block...    0.000000
# 22  abortion_status_Abortion available, pre-viabil...    0.000000
# 21             abortion_status_Abortion Ban In Effect    0.000000
# 20                 abortion_status_Abortion Available    0.000000
# 25      abortion_status_Status of pre-Roe ban unclear    0.000000
# 16                                       few_services   -0.006587
# 18                                       full_service   -0.015340
# 8                                           pap_smear   -0.066725
# 2                                  maternal_mortality   -0.209684
# 7                                         no_provider   -0.380262
# 15                                        no_services   -0.382452
# 14                          abortions_residence_state   -0.477219
# 5                                    no_doctor_visits   -0.553699
# 9                                         teen_births   -1.122156

# %%
chc2_df = clustered_df.drop(columns=['PC 1','PC 2','PC 3','prescription_contraception',
                                     'otc_methods','male_sterilization','female_sterilization','cost_sharing',
                                     'abortion_status','maternal_mortality','no_doctor_visits','no_provider',
                                     'pap_smear','teen_births','abortions_residence_state','no_services',
                                     'few_services','restricted_services','full_service',])
chc2_df.head()
# Out:
#             total_community_health_centers  uninsured  total_insured  \
# state
# Alabama                                 17     165700        1462900
# Alaska                                  27      29200         207200
# Arizona                                 23     309000        2132900
# Arkansas                                12      83800         865900
# California                             175    1034300       11885100
#
#             population  land_area_sqmi  mammogram  poverty_under_200  \
# state
# Alabama        4767100           50645       0.74              0.332
# Alaska          701700          570641       0.63              0.285
# Arizona        7098000          113594       0.68              0.298
# Arkansas       2922500           52035       0.70              0.334
# California    38642700          155779       0.68              0.272
#
#             percent_of_all_us_abortions  \
# state
# Alabama                             0.6
# Alaska                              0.1
# Arizona                             1.4
# Arkansas                            0.3
# California                         16.6
#
#             percent_residents_traveling_outside_state  \
# state
# Alabama                                            47
# Alaska                                              7
# Arizona                                             6
# Arkansas                                           37
# California                                          0
#
#             abortions_occurring_state  Class
# state
# Alabama                          5700      0
# Alaska                           1240      0
# Arizona                         13320      0
# Arkansas                         3250      0
# California                     154060      2

# %%
train2_df = chc2_df[chc2_df['Class']==4]
X_train2 = train2_df.drop(columns=['total_community_health_centers','Class'])
y_train2 = train2_df[['total_community_health_centers']]

# %%
test2_df = chc2_df[(chc2_df['Class']!=4) & (chc2_df['Class']!=2)]
X_test2 = test2_df.drop(columns=['total_community_health_centers','Class'])
y_test2 = test2_df[['total_community_health_centers']]

# %%
# Scaling the remaining columns
scalerX2 = StandardScaler().fit(X_train2)
scalery2 = StandardScaler().fit(y_train2)
X_train_scaled2 = scalerX2.transform(X_train2)
y_train_scaled2 = scalery2.transform(y_train2)
X_test_scaled2 = scalerX2.transform(X_test2)
y_test_scaled2 = scalery2.transform(y_test2)

# %%
# Creating an object of LinearRegression class
LR2 = LinearRegression()

# Fitting the training data
LR2.fit(X_train_scaled2, y_train_scaled2)
# Out:
# LinearRegression()

# %%
y_pred_scaled2 = LR2.predict(X_test_scaled2)

# %%
# Returning data to pre-scaled format
y_pred2 = scalery2.inverse_transform(y_pred_scaled2)

# %%
compare_df2 = y_test2['total_community_health_centers'].to_frame()
compare_df2['predictions'] = y_pred2.astype(int)
compare_df2['addl_chc_needed'] = compare_df2['predictions'] - compare_df2['total_community_health_centers']
compare_df2['Class'] = clustered_df['Class']
#compare_df = compare_df[compare_df['addl_chc_needed']>0]
compare_df.sort_values(by=['addl_chc_needed'],ascending=False)
# Out:
#                 total_community_health_centers  predictions  addl_chc_needed  \
# state
# Alaska                                      27          147              120
# Texas                                       72          190              118
# Florida                                     47           93               46
# South Dakota                                 4           45               41
# Wyoming                                      6           27               21
# Wisconsin                                   16           36               20
# Montana                                     14           27               13
# Rhode Island                                 8           19               11
# North Dakota                                 4           14               10
# Minnesota                                   16           24                8
# Iowa                                        14           20                6
# Missouri                                    28           31                3
# New Hampshire                               10           11                1
# Arizona                                     23           19               -4
# Idaho                                       14            9               -5
# Utah                                        13            8               -5
# Nebraska                                     7            2               -5
# Pennsylvania                                42           36               -6
# Colorado                                    19           13               -6
# South Carolina                              23           13              -10
# North Carolina                              39           28              -11
# Hawaii                                      14            3              -11
# Georgia                                     35           22              -13
# Michigan                                    39           22              -17
# Alabama                                     17           -5              -22
# West Virginia                               28            0              -28
# Kansas                                      19          -11              -30
# Tennessee                                   29           -2              -31
# Louisiana                                   36            0              -36
# Kentucky                                    25          -12              -37
# Indiana                                     27          -10              -37
# Ohio                                        51           14              -37
# Mississippi                                 20          -18              -38
# Oklahoma                                    21          -24              -45
# Arkansas                                    12          -34              -46
#
#                 Class
# state
# Alaska              0
# Texas               3
# Florida             3
# South Dakota        0
# Wyoming             0
# Wisconsin           1
# Montana             0
# Rhode Island        1
# North Dakota        0
# Minnesota           1
# Iowa                1
# Missouri            0
# New Hampshire       1
# Arizona             0
# Idaho               0
# Utah                0
# Nebraska            0
# Pennsylvania        1
# Colorado            1
# South Carolina      0
# North Carolina      1
# Hawaii              1
# Georgia             0
# Michigan            1
# Alabama             0
# West Virginia       0
# Kansas              0
# Tennessee           0
# Louisiana           0
# Kentucky            0
# Indiana             0
# Ohio                0
# Mississippi         0
# Oklahoma            0
# Arkansas            0

# %%
# Getting feature importance
importance2 = LR2.coef_

d2 = {'Feature':X_train2.columns, 'Importance':importance2[0]}
fi_df2 = pd.DataFrame(data=d2)
print(fi_df2)
fi_df.sort_values(by=['Importance'], ascending=False)
# Out:
#                                      Feature  Importance
# 0                                  uninsured   -1.061690
# 1                              total_insured   -4.471782
# 2                                 population    7.066438
# 3                             land_area_sqmi    0.045600
# 4                                  mammogram   -0.046098
# 5                          poverty_under_200    0.084878
# 6                percent_of_all_us_abortions    4.545018
# 7  percent_residents_traveling_outside_state   -0.043456
# 8                  abortions_occurring_state   -5.396517
#                                               Feature  Importance
# 4                                      land_area_sqmi    1.340777
# 10                                  poverty_under_200    0.763528
# 12          percent_residents_traveling_outside_state    0.717067
# 13                          abortions_occurring_state    0.589229
# 11                        percent_of_all_us_abortions    0.556908
# 6                                           mammogram    0.407875
# 3                                          population    0.399309
# 0                                           uninsured    0.389561
# 1                                       total_insured    0.334030
# 17                                restricted_services    0.000000
# 19  abortion_status_6 week LMP ban currently in ef...    0.000000
# 24  abortion_status_State abortion ban/restriction...    0.000000
# 23  abortion_status_Abortion ban temporarily block...    0.000000
# 22  abortion_status_Abortion available, pre-viabil...    0.000000
# 21             abortion_status_Abortion Ban In Effect    0.000000
# 20                 abortion_status_Abortion Available    0.000000
# 25      abortion_status_Status of pre-Roe ban unclear    0.000000
# 16                                       few_services   -0.006587
# 18                                       full_service   -0.015340
# 8                                           pap_smear   -0.066725
# 2                                  maternal_mortality   -0.209684
# 7                                         no_provider   -0.380262
# 15                                        no_services   -0.382452
# 14                          abortions_residence_state   -0.477219
# 5                                    no_doctor_visits   -0.553699
# 9                                         teen_births   -1.122156

# %%
# using only population, land area, and Class (cluster output) as features
chc2_df = clustered_df[['total_community_health_centers','population','land_area_sqmi','Class']]
chc2_df
# Out:
#                       total_community_health_centers  population  \
# state
# Alabama                                           17     4767100
# Alaska                                            27      701700
# Arizona                                           23     7098000
# Arkansas                                          12     2922500
# California                                       175    38642700
# Colorado                                          19     5611800
# Connecticut                                       16     3453300
# Delaware                                           3      940300
# District of Columbia                               8      671300
# Florida                                           47    20992000
# Georgia                                           35    10294000
# Hawaii                                            14     1343000
# Idaho                                             14     1750900
# Illinois                                          45    12362300
# Indiana                                           27     6511800
# Iowa                                              14     3060200
# Kansas                                            19     2811200
# Kentucky                                          25     4319300
# Louisiana                                         36     4498600
# Maine                                             18     1302300
# Maryland                                          17     5875500
# Massachusetts                                     37     6650800
# Michigan                                          39     9765600
# Minnesota                                         16     5514800
# Mississippi                                       20     2867100
# Missouri                                          28     5939900
# Montana                                           14     1039400
# Nebraska                                           7     1873600
# Nevada                                             8     3029700
# New Hampshire                                     10     1314000
# New Jersey                                        23     8699400
# New Mexico                                        16     2041400
# New York                                          63    18908300
# North Carolina                                    39    10139700
# North Dakota                                       4      731000
# Ohio                                              51    11351500
# Oklahoma                                          21     3826900
# Oregon                                            30     4128900
# Pennsylvania                                      42    12377600
# Rhode Island                                       8     1017100
# South Carolina                                    23     4984200
# South Dakota                                       4      851300
# Tennessee                                         29     6640900
# Texas                                             72    28286200
# Utah                                              13     3154100
# Vermont                                           11      598100
# Virginia                                          26     8185100
# Washington                                        27     7423900
# West Virginia                                     28     1739000
# Wisconsin                                         16     5677100
# Wyoming                                            6      562700
#
#                       land_area_sqmi  Class
# state
# Alabama                        50645      0
# Alaska                        570641      0
# Arizona                       113594      0
# Arkansas                       52035      0
# California                    155779      2
# Colorado                      103642      1
# Connecticut                     4842      4
# Delaware                        1949      4
# District of Columbia              61      4
# Florida                        53625      3
# Georgia                        57513      0
# Hawaii                          6423      1
# Idaho                          82643      0
# Illinois                       55519      4
# Indiana                        35826      0
# Iowa                           55857      1
# Kansas                         81759      0
# Kentucky                       39486      0
# Louisiana                      43204      0
# Maine                          30843      4
# Maryland                        9707      4
# Massachusetts                   7800      4
# Michigan                       56539      1
# Minnesota                      79627      1
# Mississippi                    46923      0
# Missouri                       68742      0
# Montana                       145546      0
# Nebraska                       76824      0
# Nevada                        109781      4
# New Hampshire                   8953      1
# New Jersey                      7354      4
# New Mexico                    121298      4
# New York                       47126      2
# North Carolina                 48618      1
# North Dakota                   69001      0
# Ohio                           40861      0
# Oklahoma                       68595      0
# Oregon                         95988      4
# Pennsylvania                   44743      1
# Rhode Island                    1034      1
# South Carolina                 30061      0
# South Dakota                   75811      0
# Tennessee                      41235      0
# Texas                         261232      3
# Utah                           82170      0
# Vermont                         9217      4
# Virginia                       39490      4
# Washington                     66456      4
# West Virginia                  24038      0
# Wisconsin                      54158      1
# Wyoming                        97093      0

# %%
#training_df = chc2_df[(chc_df['Class']==4) | (chc_df['Class']==2)]
training2_df = chc2_df[chc2_df['Class']==4]
X_train2 = training2_df.drop(columns='total_community_health_centers')
y_train2 = training2_df['total_community_health_centers']

# %%
fit2_df = chc2_df
X2 = fit2_df.drop(columns=['total_community_health_centers'])
y2 = fit2_df[['total_community_health_centers']]

# %%
# Creating an object of LinearRegression class
LR = LinearRegression()

# Fitting the training data
LR.fit(X_train2, y_train2)
# Out:
# LinearRegression()

# %%
y_pred2 = LR.predict(X2)
y_pred2
# Out:
# array([ 20.93461749,  25.3555075 ,  29.05046266,  16.02234673,
#        115.00112832,  24.76605675,  16.05570467,   9.22226197,
#          8.44423349,  64.59093395,  35.97847458,  10.43558836,
#         13.77907482,  41.47362737,  25.18253126,  16.50484242,
#         16.60020433,  19.40300633,  19.99414217,  11.04658177,
#         22.70348931,  24.7291396 ,  34.53084319,  23.79724587,
#         15.72280026,  24.61769852,  13.72386359,  13.9369235 ,
#         18.01346604,  10.43233926,  30.21705164,  15.69930428,
#         58.80392108,  35.30177167,  10.63797652,  38.32699752,
#         18.93936342,  20.55829334,  41.19686679,   9.40150303,
#         20.9104531 ,  11.16188139,  25.68874316,  90.30142058,
#         17.53310998,   8.51773329,  29.78388448,  28.53522874,
#         12.01852602,  23.48184171,  11.01463615])

# %%
compare2_df = y2['total_community_health_centers'].to_frame()
compare2_df['predictions'] = y_pred2.astype(int)
compare2_df['addl_chc_needed'] = compare2_df['predictions'] - compare2_df['total_community_health_centers']
compare2_df['Class'] = clustered_df['Class']
compare2_df = compare2_df[compare2_df['addl_chc_needed']>0]
compare2_df.sort_values(by=['addl_chc_needed'],ascending=False)
# Out:
#               total_community_health_centers  predictions  addl_chc_needed  \
# state
# Texas                                     72           90               18
# Florida                                   47           64               17
# Nevada                                     8           18               10
# New Jersey                                23           30                7
# Wisconsin                                 16           23                7
# South Dakota                               4           11                7
# Minnesota                                 16           23                7
# Delaware                                   3            9                6
# North Dakota                               4           10                6
# Nebraska                                   7           13                6
# Arizona                                   23           29                6
# Wyoming                                    6           11                5
# Maryland                                  17           22                5
# Colorado                                  19           24                5
# Utah                                      13           17                4
# Arkansas                                  12           16                4
# Virginia                                  26           29                3
# Alabama                                   17           20                3
# Iowa                                      14           16                2
# Rhode Island                               8            9                1
# Washington                                27           28                1
#
#               Class
# state
# Texas             3
# Florida           3
# Nevada            4
# New Jersey        4
# Wisconsin         1
# South Dakota      0
# Minnesota         1
# Delaware          4
# North Dakota      0
# Nebraska          0
# Arizona           0
# Wyoming           0
# Maryland          4
# Colorado          1
# Utah              0
# Arkansas          0
# Virginia          4
# Alabama           0
# Iowa              1
# Rhode Island      1
# Washington        4
