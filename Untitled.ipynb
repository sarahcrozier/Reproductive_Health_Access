# %%
import pandas as pd

# %%
health_df = pd.read_csv("merged.csv")

# %%
health_df.head()
# Out:
#      Location             Status of Abortion  Total Community Health Centers  \
# 0     Alabama         Abortion Ban In Effect                              17
# 1      Alaska             Abortion Available                              27
# 2     Arizona  Status of pre-Roe ban unclear                              23
# 3    Arkansas         Abortion Ban In Effect                              12
# 4  California             Abortion Available                             175
#
#    Employer Insured  Non-Group Insured  Medicaid Insured Medicare Insured  \
# 0            889200              55300            208500          83800.0
# 1            101500               9000             42400                .
# 2           1202400              98500            443300                .
# 3            466400              89200            183300          29100.0
# 4           6793100             995200           2659000         212500.0
#
# ...
